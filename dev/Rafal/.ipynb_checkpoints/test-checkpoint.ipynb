# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', 999)
from api_keys import g_key
import requests
import gmaps
import os
from pathlib import Path
import gmaps.geojson_geometries
import gmaps.datasets
import geopandas as gpd
from shapely.geometry import Point, Polygon
import seaborn as sns
import shapefile as shp

# %%
file = Path("RAW DATA/nynta(3).csv")
data = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-7d1cb0b73f8c> in <module>
#       1 file = Path("RAW DATA/nynta(3).csv")
# ----> 2 data = pd.read_csv(file)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'RAW DATA/nynta(3).csv' does not exist: b'RAW DATA/nynta(3).csv'

# %%
sf_path = Path("RAW DATA/Neighborhood Tabulation Areas (NTA)/geo_export_196ffd4c-8e62-442e-8074-99964842e3a9.shp")
sf = gpd.read_file(sf_path, encoding='utf-8')
nyc_sf = sf
nyc_shape = nyc_sf.to_crs({'init': 'epsg:4326'})
nyc_shape
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#      boro_code      boro_name county_fip ntacode  \
# 0          3.0       Brooklyn        047    BK88
# 1          4.0         Queens        081    QN51
# 2          4.0         Queens        081    QN27
# 3          4.0         Queens        081    QN07
# 4          1.0      Manhattan        061    MN06
# ..         ...            ...        ...     ...
# 190        4.0         Queens        081    QN56
# 191        4.0         Queens        081    QN57
# 192        2.0          Bronx        005    BX36
# 193        5.0  Staten Island        085    SI35
# 194        5.0  Staten Island        085    SI22
#
#                                        ntaname    shape_area    shape_leng  \
# 0                                 Borough Park  5.400502e+07  39247.227831
# 1                                  Murray Hill  5.248828e+07  33266.904797
# 2                                East Elmhurst  1.972685e+07  19816.712074
# 3                                       Hollis  2.288777e+07  20976.335574
# 4                               Manhattanville  1.064708e+07  17040.685413
# ..                                         ...           ...           ...
# 190                                 Ozone Park  2.501684e+07  24731.699084
# 191                    Lindenwood-Howard Beach  6.455895e+07  79085.800116
# 192          University Heights-Morris Heights  2.125549e+07  24100.432040
# 193                   New Brighton-Silver Lake  4.713724e+07  30320.374973
# 194  West New Brighton-New Brighton-St. George  5.603045e+07  66054.251484
#
#                                               geometry
# 0    POLYGON ((-73.97605 40.63128, -73.97717 40.630...
# 1    POLYGON ((-73.80379 40.77561, -73.80099 40.775...
# 2    POLYGON ((-73.86110 40.76366, -73.85993 40.762...
# 3    POLYGON ((-73.75726 40.71814, -73.75589 40.716...
# 4    POLYGON ((-73.94608 40.82126, -73.94640 40.820...
# ..                                                 ...
# 190  POLYGON ((-73.84013 40.68115, -73.83952 40.679...
# 191  MULTIPOLYGON (((-73.85722 40.65028, -73.85902 ...
# 192  POLYGON ((-73.90487 40.85869, -73.90526 40.858...
# 193  POLYGON ((-74.08373 40.63574, -74.08395 40.635...
# 194  POLYGON ((-74.07258 40.63794, -74.07330 40.637...
#
# [195 rows x 8 columns]
